# %% [markdown]
# <h1 style="background: linear-gradient(to right, #ff7e5f, #feb47b);-webkit-background-clip: text;color: white;">🎯JOB PREDICTION PROJECT</h1>

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">📦 IMPORTING LIBRARIES</h1>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px;">📥LOADING DATASET</h1>

# %%
df=pd.read_csv(r"C:\Users\nithi\Downloads\job_search_platform_efficacy_100k.csv")

# %%
df #imported data set
# Out:
#        Student_ID University_Rating School_Size     Region Major_Category  \
# 0      STU_000001          Mid-tier      Medium       West     Healthcare
# 1      STU_000002        Lower-tier      Medium  Northeast           STEM
# 2      STU_000003        Lower-tier      Medium    Midwest           STEM
# 3      STU_000004          Mid-tier      Medium    Midwest       Business
# 4      STU_000005          Mid-tier      Medium      South       Business
# ...           ...               ...         ...        ...            ...
# 99995  STU_099996        Lower-tier       Large  Northeast           STEM
# 99996  STU_099997        Lower-tier       Large       West       Business
# 99997  STU_099998        Lower-tier       Small  Northeast       Business
# 99998  STU_099999          Mid-tier       Large    Midwest       Business
# 99999  STU_100000          Mid-tier       Small    Midwest           STEM
#
#         GPA  Prior_Internships  Extra_Curricular_Activities  \
# ...

# %%
df_copy=df.copy #creating duplicate/backingup the dataset

# %% [markdown]
# <h3 style="color:#B95613; font-size:20px">🔍 BASIC INSPECTIONS</h3>

# %%
print(df.head()) #Provides first top 5 data set details
# Out:
#    Student_ID University_Rating School_Size     Region Major_Category   GPA  \
# 0  STU_000001          Mid-tier      Medium       West     Healthcare  2.81
# 1  STU_000002        Lower-tier      Medium  Northeast           STEM  2.61
# 2  STU_000003        Lower-tier      Medium    Midwest           STEM  3.53
# 3  STU_000004          Mid-tier      Medium    Midwest       Business  2.73
# 4  STU_000005          Mid-tier      Medium      South       Business  4.00
#
#    Prior_Internships  Extra_Curricular_Activities  Networking_Events_Attended  \
# 0                  3                            2                           6
# 1                  1                            1                           6
# 2                  3                            2                           2
# 3                  0                            2                           1
# 4                  1                            0                           1
#
# ...

# %%
print(df.shape) #shape function provide information about the count of rows and columns
# Out:
# (100000, 20)

# %%
print(df.columns) #column funtion provides the each column name that are present in the data set
# Out:
# Index(['Student_ID', 'University_Rating', 'School_Size', 'Region',
#        'Major_Category', 'GPA', 'Prior_Internships',
#        'Extra_Curricular_Activities', 'Networking_Events_Attended',
#        'Primary_Search_Platform', 'Months_Searching', 'Applications_Submitted',
#        'First_Round_Interviews', 'Second_Round_Interviews', 'Offer_Received',
#        'Time_to_Offer_Days', 'Offer_Salary', 'Company_Size_Offered',
#        'Role_Relevance', 'Accepted_Offer'],
#       dtype='object')

# %%
print(df.info()) #info function summarize of the dataset including number of rows, columns, data types, and missing values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Student_ID                   100000 non-null  object
#  1   University_Rating            100000 non-null  object
#  2   School_Size                  100000 non-null  object
#  3   Region                       100000 non-null  object
#  4   Major_Category               100000 non-null  object
#  5   GPA                          100000 non-null  float64
#  6   Prior_Internships            100000 non-null  int64
#  7   Extra_Curricular_Activities  100000 non-null  int64
#  8   Networking_Events_Attended   100000 non-null  int64
#  9   Primary_Search_Platform      100000 non-null  object
#  10  Months_Searching             100000 non-null  int64
#  11  Applications_Submitted       100000 non-null  int64
# ...

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🧹Data Cleaning – Missing Values</h1>

# %%
#checking null values
print(df.isnull().sum())
# Out:
# Student_ID                         0
# University_Rating                  0
# School_Size                        0
# Region                             0
# Major_Category                     0
# GPA                                0
# Prior_Internships                  0
# Extra_Curricular_Activities        0
# Networking_Events_Attended         0
# Primary_Search_Platform            0
# Months_Searching                   0
# Applications_Submitted             0
# First_Round_Interviews             0
# Second_Round_Interviews            0
# Offer_Received                     0
# Time_to_Offer_Days             65771
# Offer_Salary                   65771
# Company_Size_Offered           65771
# Role_Relevance                 65771
# Accepted_Offer                 65771
# dtype: int64

# %%
num_cols=df.select_dtypes(include=np.number).columns
#creating new variable and storing the column which contains numeric values in  it

# %%
num_cols
# Out:
# Index(['GPA', 'Prior_Internships', 'Extra_Curricular_Activities',
#        'Networking_Events_Attended', 'Months_Searching',
#        'Applications_Submitted', 'First_Round_Interviews',
#        'Second_Round_Interviews', 'Offer_Received', 'Time_to_Offer_Days',
#        'Offer_Salary', 'Role_Relevance', 'Accepted_Offer'],
#       dtype='object')

# %%
df[num_cols]=df[num_cols].fillna(df[num_cols].median())
#adding median value to the null values using fillna function

# %%
print(df.isnull().sum())
# Out:
# Student_ID                         0
# University_Rating                  0
# School_Size                        0
# Region                             0
# Major_Category                     0
# GPA                                0
# Prior_Internships                  0
# Extra_Curricular_Activities        0
# Networking_Events_Attended         0
# Primary_Search_Platform            0
# Months_Searching                   0
# Applications_Submitted             0
# First_Round_Interviews             0
# Second_Round_Interviews            0
# Offer_Received                     0
# Time_to_Offer_Days                 0
# Offer_Salary                       0
# Company_Size_Offered           65771
# Role_Relevance                     0
# Accepted_Offer                     0
# dtype: int64

# %%
cat_cols=df.select_dtypes(include="object").columns
#creating new variable and storing column which contains categorial data(string objects)
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
#filling mode value to the place of null value using fillna function

# %%
print(df.isnull().sum())
# Out:
# Student_ID                     0
# University_Rating              0
# School_Size                    0
# Region                         0
# Major_Category                 0
# GPA                            0
# Prior_Internships              0
# Extra_Curricular_Activities    0
# Networking_Events_Attended     0
# Primary_Search_Platform        0
# Months_Searching               0
# Applications_Submitted         0
# First_Round_Interviews         0
# Second_Round_Interviews        0
# Offer_Received                 0
# Time_to_Offer_Days             0
# Offer_Salary                   0
# Company_Size_Offered           0
# Role_Relevance                 0
# Accepted_Offer                 0
# dtype: int64

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🔍 DUPLICATES DETECTION & REMOVAL</h1>

# %%
df=df.drop_duplicates()
#removing the duplicate rows from the data set using drop_duplicate function


df.columns=df.columns.str.strip()
#removing the extra space from the columns using strip function

for col in cat_cols:
    df[col]=df[col].str.lower().str.strip()
#converting the text to lowercase

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🧮 DESCRIPTIVE STATISTICS</h1>

# %%
print(df.describe()) #This will provide summary for the numeramic values column
# Out:
#                  GPA  Prior_Internships  Extra_Curricular_Activities  \
# count  100000.000000       100000.00000                100000.000000
# mean        3.196631            1.19697                     2.003990
# std         0.392370            1.12192                     1.413709
# min         2.000000            0.00000                     0.000000
# 25%         2.930000            0.00000                     1.000000
# 50%         3.200000            1.00000                     2.000000
# 75%         3.470000            2.00000                     3.000000
# max         4.000000            5.00000                    11.000000
#
#        Networking_Events_Attended  Months_Searching  Applications_Submitted  \
# count               100000.000000     100000.000000           100000.000000
# mean                     2.998600          6.499680               53.727620
# std                      1.734494          3.443719               45.004663
# ...

# %%
print(df.describe(include="object")) #This will give the summary of the categorial(Object) column
# Out:
#         Student_ID University_Rating School_Size  Region Major_Category  \
# count       100000            100000      100000  100000         100000
# unique      100000                 3           3       4              5
# top     stu_000001          mid-tier       large   south           stem
# freq             1             50022       40169   25099          35102
#
#        Primary_Search_Platform Company_Size_Offered
# count                   100000               100000
# unique                       3                    3
# top                   linkedin           enterprise
# freq                     39573                79679

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🏷️ VALUE COUNTS</h1>

# %%
for col in cat_cols:
    print(f"\n{col} value counts:\n" , df[col].value_counts())
#This is to check the repeated values
# Out:
# Student_ID value counts:
#  Student_ID
# stu_000001    1
# stu_066651    1
# stu_066673    1
# stu_066672    1
# stu_066671    1
#              ..
# stu_033332    1
# stu_033331    1
# stu_033330    1
# stu_033329    1
# stu_100000    1
# Name: count, Length: 100000, dtype: int64
#
# University_Rating value counts:
#  University_Rating
# mid-tier      50022
# lower-tier    34962
# top-tier      15016
# Name: count, dtype: int64
#
# School_Size value counts:
#  School_Size
# large     40169
# medium    39896
# small     19935
# Name: count, dtype: int64
#
# Region value counts:
#  Region
# south        25099
# west         25047
# northeast    24986
# midwest      24868
# Name: count, dtype: int64
#
# Major_Category value counts:
#  Major_Category
# stem          35102
# business      29970
# humanities    15030
# healthcare    14915
# arts           4983
# Name: count, dtype: int64
#
# Primary_Search_Platform value counts:
#  Primary_Search_Platform
# linkedin     39573
# ...

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">📦 IMPORTING LIBRARIES</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🔗 Correlation Insights</h1>

# %%
#Correlation analysis helps to find the relationship between the columns
plt.figure(figsize=(10,6)) #setting up the graph size
sns.heatmap(df.corr(numeric_only=True), annot=True,cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
#🔴 Red (1)   | strong positive relation |
#🔵 Blue (-1) | strong negative relation |
#⚪ Light      | weak/no relation         |

# %% [markdown]
# <h1 style="color:#B95613; font-size:20px">🧪 EXPLORATORY DATA ANALYSIS</h1>

# %% [markdown]
# <h1 style="color:purple; font-size:14px">📈DISTRIBUTION PLOTS (HISTOGRAMS+KDE)</h1>

# %%
num_cols=["GPA","Applications_Submitted","Offer_Salary","Time_to_Offer_Days"]
colors=["blue","green","orange","purple"]

# %%
for col, color in zip(num_cols,colors):
    plt.figure()
    sns.histplot(df[col], kde=True, color=color, bins=30)
    plt.title(f"Distribution of{col}",fontsize=14)
    plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🗃️COUNT PLOTS (CATEGORIAL ANALYSIS)</h1>

# %%
cat_cols=["Region","Major_Category","Primary_Search_Platform","Company_Size_Offered"]
palette_list=["Set1","Set2","coolwarm","viridis"]
for col, pal in zip(cat_cols,palette_list):
    plt.figure()
    sns.countplot(data=df,x=col,palette=pal)
    plt.xticks(rotation=45)
    plt.title(f"count of{col}")
    plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🎯GPA vs OFFER SALARY (SCATTER PLOT)</h1>

# %%
plt.figure()
sns.scatterplot(
    data=df,
    x="GPA",
    y="Offer_Salary",
    hue="Accepted_Offer",
    palette="coolwarm",
    alpha=0.7
)
plt.title("GPA vs Offer Salary")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">>🧬 APPLICATIONS vs INTERVIEWS (MULTI-VARIABLE SCATTER)</h1>

# %%
plt.figure()
sns.scatterplot(
    data=df,
    x="Applications_Submitted",
    y="First_Round_Interviews",
    hue="Second_Round_Interviews",
    palette="viridis",
    size="GPA"
)
plt.title("Application vs Interviews")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">💰 BOX PLOTS(SALARY INSIGHTS)</h1>

# %%
plt.figure()
sns.boxplot(
    data=df,
    x="Company_Size_Offered",
    y="Offer_Salary",
    palette="Set3"
)
plt.title("Salary by Company Size")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🎻 VIOLIN PLOT (DISTRIBUTION + DENSITY)</h1>

# %%
plt.figure()
sns.violinplot(
    data=df,
    x="Primary_Search_Platform",
    y="Time_to_Offer_Days",
    palette="muted"
)
plt.xticks(rotation=45)
plt.title("Time to Offer by Platform")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🔥 CORRELATION HEATMAP</h1>

# %%
plt.figure(figsize=(12,8))
corr = df.corr(numeric_only=True)

sns.heatmap(corr,
           annot=True,
           cmap="coolwarm",
           fmt=".2f",
           linewidth=0.5
)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🗺️ BAR PLOT (AVERAGE SALARY BY REGION)</h1>

# %%
plt.figure()
avg_salary=df.groupby("Region")["Offer_Salary"].mean().reset_index()

sns.barplot(
    data=avg_salary,
    x="Region",
    y="Offer_Salary",
    palette="Spectral"
)
plt.xticks(rotation=45)
plt.title("Average Salary by Region")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">📈 LINE PLOT (TREND ANALYSIS)</h1>

# %%
plt.figure()
trend=df.groupby("Months_Searching")["Offer_Salary"].mean()

sns.lineplot(
    x=trend.index,
    y=trend.values,
    color="red",
    marker="o"
)
plt.title("Salary vs Job Search Duration")
plt.xlabel("Months Searching")
plt.ylabel("Average Salary")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">✅ Pie Chart (Offer Acceptance Rate)</h1>

# %%
plt.figure()
df["Accepted_Offer"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    colors=["skyblue","orange"]
)
plt.title("Offer Acceptance Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# <h1 style="color:purple; font-size:14px">📚 ADAVANCED: STACKED BAR PLOT</h1>

# %%
cross_tab=pd.crosstab(df["Primary_Search_Platform"],df["Accepted_Offer"])
cross_tab.plot(
    kind="bar",
    stacked=True,
    colormap="coolwarm"
)
plt.title("Platform vs Offer Acceptance")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1 style="color:purple; font-size:14px">🧩FEATURE ENGINEERING</h1>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report,roc_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import auc

# %%
df=df.drop(columns=["Student_ID"],errors="ignore")

#Target
x=df.drop(columns=["Offer_Received"])
y=df["Offer_Received"]

#split
x_train, x_test,y_train, y_test=train_test_split( x,y, test_size=0.2,random_state=42,stratify=y)

#Separate columns
cats_cols=x_train.select_dtypes(include="object").columns
nums_cols= x_train.select_dtypes(include=np.number).columns

#SAFE Encoding(handles unseen values)
encoder=OrdinalEncoder(handle_unknown="use_encoded_value",unknown_value=-1)
x_train[cat_cols] = encoder.fit_transform(x_train[cat_cols])
x_test[cat_cols] = encoder.transform(x_test[cat_cols])

cat_cols = x_train.select_dtypes(include='object').columns

encoder = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)

x_train[cat_cols] = encoder.fit_transform(x_train[cat_cols])
x_test[cat_cols] = encoder.transform(x_test[cat_cols])

#Scaling
scaler = StandardScaler()

x_train[num_cols] = scaler.fit_transform(x_train[num_cols])
x_test[num_cols] = scaler.transform(x_test[num_cols])

#Models
models={"Logistic Regression":LogisticRegression(),"Random Forest":RandomForestClassifier(n_estimators=100)}

roc_data={}

#Training
for name, model in models.items():
    model.fit(x_train,y_train)

    y_pred=model.predict(x_test)
    acc=accuracy_score(y_test,y_pred)*100
    print(f"\n{name}Accuracy:{acc:.2f}%")
    print(classification_report(y_test,y_pred))

    #ROC
    y_prob=model.predict_proba(x_test)[:,1]
    fpr,tpr,_=roc_curve(y_test,y_prob)
    roc_auc=auc(fpr,tpr)

    roc_data[name]=(fpr,tpr,roc_auc)

#ROC Plot
plt.figure()

for name,(fpr,tpr,roc_auc) in roc_data.items():
    plt.plot(fpr,tpr,label=f"{name} AUC={roc_auc:.2f}")
plt.plot([0,1],[0,1],"--")
plt.legend()
plt.title("ROC CURVE")
plt.show()
# Out:
# Logistic RegressionAccuracy:92.86%
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     13154
#            1       0.95      0.83      0.89      6846
#
#     accuracy                           0.93     20000
#    macro avg       0.93      0.91      0.92     20000
# weighted avg       0.93      0.93      0.93     20000
#
#
# Random ForestAccuracy:100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13154
#            1       1.00      1.00      1.00      6846
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000
